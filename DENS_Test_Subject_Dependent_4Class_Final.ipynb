# %%
import scipy.io as sio
import numpy as np
import pickle as pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize
from sklearn.metrics import confusion_matrix, classification_report, f1_score, plot_confusion_matrix
from scipy.signal import spectrogram
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from scipy import signal
import os
import math

# %%
import tensorflow as tf
import keras

from tensorflow.keras.utils import to_categorical 
from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
from keras.models import Sequential, load_model
from keras.layers import Activation, Dropout, Flatten, Dense, LSTM, Conv2D, MaxPooling2D, RepeatVector
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
os.getcwd()
os.chdir('/content/drive/My Drive')

# %%
_,_, files = next(os.walk('/content/drive/My Drive/MTech_Thesis/DENS/Emotional'))
files_count = len(files)

# %%
files
# Out:
# ['Joyous_mit003Trial-2Click-1.mat',
#  'Afraid_mit003Trial-6Click-2.mat',
#  'Angry_mit003Trial-7Click-4.mat',
#  'Hate_mit003Trial-7Click-3.mat',
#  'Hate_mit003Trial-10Click-6.mat',
#  'Alarmed_mit003Trial-9Click-5.mat',
#  'Sad_mit003Trial-11Click-7.mat',
#  'Amused_mit004Trial-3Click-1.mat',
#  'Adventorous_mit004Trial-4Click-3.mat',
#  'Excited_mit004Trial-4Click-2.mat',
#  'Disgust_mit004Trial-5Click-4.mat',
#  'Disgust_mit004Trial-5Click-5.mat',
#  'Happy_mit004Trial-8Click-6.mat',
#  'Happy_mit004Trial-8Click-7.mat',
#  'Taken Aback_mit004Trial-11Click-9.mat',
#  'Distress_mit007Trial-3Click-2.mat',
#  'Miserable_mit007Trial-2Click-1.mat',
#  'Despondent_mit007Trial-4Click-4.mat',
#  'Miserable_mit007Trial-4Click-3.mat',
#  'Happy_mit007Trial-7Click-6.mat',
#  'Hate_mit007Trial-5Click-5.mat',
#  'Joyous_mit007Trial-7Click-7.mat',
#  'Calm_mit014Trial-1Click-1.mat',
#  'Pensive_mit014Trial-1Click-3.mat',
#  'Pensive_mit014Trial-1Click-2.mat',
#  'Amused_mit014Trial-2Click-4.mat',
#  'Excited_mit014Trial-2Click-5.mat',
#  'Amused_mit014Trial-3Click-7.mat',
#  'Distress_mit014Trial-2Click-6.mat',
#  'Disgust_mit014Trial-4Click-9.mat',
#  'Tense_mit014Trial-4Click-8.mat',
#  'Hate_mit014Trial-6Click-11.mat',
#  'Startled_mit014Trial-4Click-10.mat',
#  'Hate_mit014Trial-6Click-12.mat',
#  'Hate_mit014Trial-6Click-13.mat',
#  'Sad_mit014Trial-7Click-15.mat',
#  'Angry_mit014Trial-6Click-14.mat',
#  'Melancholic_mit014Trial-7Click-16.mat',
#  'Disgust_mit014Trial-8Click-17.mat',
#  'Distress_mit014Trial-9Click-18.mat',
#  'Distress_mit014Trial-9Click-19.mat',
#  'Calm_mit017Trial-1Click-1.mat',
#  'Startled_mit017Trial-2Click-2.mat',
#  'Miserable_mit017Trial-3Click-4.mat',
#  'Disgust_mit017Trial-3Click-5.mat',
#  'Calm_mit017Trial-3Click-3.mat',
#  'Taken Aback_mit017Trial-4Click-6.mat',
#  'Frustrated_mit017Trial-4Click-7.mat',
#  'Dissatisfied_mit017Trial-10Click-9.mat',
#  'Alarmed_mit017Trial-7Click-8.mat',
#  'Alarmed_mit017Trial-10Click-10.mat',
#  'Excited_mit022Trial-1Click-1.mat',
#  'Sad_mit022Trial-2Click-2.mat',
#  'Tense_mit022Trial-2Click-3.mat',
#  'Frustrated_mit022Trial-2Click-4.mat',
#  'Joyous_mit022Trial-3Click-5.mat',
#  'Happy_mit022Trial-3Click-6.mat',
#  'Happy_mit022Trial-3Click-7.mat',
#  'Happy_mit022Trial-3Click-8.mat',
#  'Afraid_mit022Trial-4Click-9.mat',
#  'Afraid_mit022Trial-6Click-12.mat',
#  'Hate_mit022Trial-4Click-11.mat',
#  'Hate_mit022Trial-4Click-10.mat',
#  'Afraid_mit022Trial-6Click-13.mat',
#  'Frustrated_mit022Trial-6Click-14.mat',
#  'Adventorous_mit022Trial-7Click-15.mat',
#  'Adventorous_mit022Trial-7Click-16.mat',
#  'Disgust_mit022Trial-8Click-17.mat',
#  'Tense_mit022Trial-9Click-20.mat',
#  'Tense_mit022Trial-8Click-18.mat',
#  'Disgust_mit022Trial-9Click-22.mat',
#  'Angry_mit022Trial-9Click-21.mat',
#  'Hate_mit022Trial-9Click-23.mat',
#  'Passionate_mit022Trial-10Click-24.mat',
#  'Alarmed_mit022Trial-11Click-26.mat',
#  'Alarmed_mit022Trial-11Click-25.mat',
#  'Disgust_mit022Trial-11Click-27.mat',
#  'Relaxed_mit023Trial-2Click-1.mat',
#  'Angry_mit023Trial-4Click-3.mat',
#  'Amused_mit023Trial-2Click-2.mat',
#  'Disgust_mit023Trial-5Click-5.mat',
#  'Disgust_mit023Trial-5Click-4.mat',
#  'Afraid_mit023Trial-8Click-8.mat',
#  'Frustrated_mit023Trial-6Click-7.mat',
#  'Afraid_mit023Trial-6Click-6.mat',
#  'Triumphant_mit023Trial-10Click-9.mat',
#  'Afraid_mit023Trial-11Click-10.mat',
#  'Sad_mit024Trial-7Click-1.mat',
#  'Sad_mit024Trial-7Click-2.mat',
#  'Adventorous_mit024Trial-9Click-4.mat',
#  'Happy_mit024Trial-9Click-3.mat',
#  'Despondent_mit024Trial-10Click-6.mat',
#  'Adventorous_mit024Trial-9Click-5.mat',
#  'Melancholic_mit024Trial-10Click-8.mat',
#  'Despondent_mit024Trial-10Click-7.mat',
#  'Angry_mit032Trial-3Click-1.mat',
#  'Angry_mit032Trial-3Click-2.mat',
#  'Startled_mit032Trial-5Click-3.mat',
#  'Hate_mit032Trial-5Click-4.mat',
#  'Sad_mit032Trial-7Click-5.mat',
#  'Sad_mit032Trial-7Click-6.mat',
#  'Sad_mit032Trial-8Click-7.mat',
#  'Aroused_mit032Trial-10Click-9.mat',
#  'Sad_mit032Trial-8Click-8.mat',
#  'Afraid_mit032Trial-11Click-10.mat',
#  'Disgust_mit035Trial-2Click-3.mat',
#  'Angry_mit035Trial-2Click-2.mat',
#  'Disgust_mit035Trial-2Click-4.mat',
#  'Disgust_mit035Trial-2Click-5.mat',
#  'Miserable_mit035Trial-3Click-6.mat',
#  'Despondent_mit035Trial-4Click-8.mat',
#  'Miserable_mit035Trial-3Click-7.mat',
#  'Miserable_mit035Trial-6Click-10.mat',
#  'Angry_mit035Trial-6Click-9.mat',
#  'Sad_mit035Trial-6Click-11.mat',
#  'Angry_mit035Trial-6Click-12.mat',
#  'Alarmed_mit035Trial-10Click-15.mat',
#  'Afraid_mit035Trial-7Click-13.mat',
#  'Adventorous_mit035Trial-11Click-17.mat',
#  'Startled_mit035Trial-10Click-16.mat',
#  'Excited_mit035Trial-11Click-18.mat',
#  'Adventorous_mit035Trial-11Click-19.mat',
#  'Angry_mit039Trial-3Click-3.mat',
#  'Disgust_mit039Trial-2Click-2.mat',
#  'Disgust_mit039Trial-2Click-1.mat',
#  'Disgust_mit039Trial-8Click-6.mat',
#  'Disgust_mit039Trial-7Click-5.mat',
#  'Afraid_mit039Trial-5Click-4.mat',
#  'Excited_mit040Trial-4Click-2.mat',
#  'Delighted_mit040Trial-4Click-3.mat',
#  'Joyous_mit040Trial-4Click-1.mat',
#  'Despondent_mit040Trial-11Click-5.mat',
#  'Sad_mit040Trial-9Click-4.mat',
#  'Happy_mit051Trial-2Click-1.mat',
#  'Despondent_mit051Trial-3Click-5.mat',
#  'Taken Aback_mit051Trial-3Click-4.mat',
#  'Alarmed_mit051Trial-4Click-7.mat',
#  'Miserable_mit051Trial-3Click-6.mat',
#  'Afraid_mit051Trial-4Click-8.mat',
#  'Sad_mit051Trial-5Click-11.mat',
#  'Sad_mit051Trial-5Click-12.mat',
#  'Angry_mit051Trial-6Click-13.mat',
#  'Angry_mit051Trial-6Click-14.mat',
#  'Excited_mit051Trial-9Click-16.mat',
#  'Delighted_mit051Trial-9Click-17.mat',
#  'Alarmed_mit051Trial-10Click-19.mat',
#  'Excited_mit052Trial-3Click-1.mat',
#  'Excited_mit052Trial-3Click-2.mat',
#  'Excited_mit052Trial-3Click-3.mat',
#  'Joyous_mit052Trial-4Click-4.mat',
#  'Amused_mit052Trial-4Click-5.mat',
#  'Amused_mit052Trial-4Click-7.mat',
#  'Amused_mit052Trial-4Click-6.mat',
#  'Angry_mit052Trial-5Click-9.mat',
#  'Angry_mit052Trial-5Click-10.mat',
#  'Startled_mit052Trial-5Click-8.mat',
#  'Angry_mit052Trial-5Click-12.mat',
#  'Startled_mit052Trial-5Click-11.mat',
#  'Dissatisfied_mit052Trial-6Click-15.mat',
#  'Sad_mit052Trial-6Click-14.mat',
#  'Sad_mit052Trial-6Click-13.mat',
#  'Angry_mit052Trial-7Click-17.mat',
#  'Depressed_mit052Trial-6Click-16.mat',
#  'Tense_mit052Trial-7Click-18.mat',
#  'Dissatisfied_mit052Trial-8Click-19.mat',
#  'Dissatisfied_mit052Trial-8Click-20.mat',
#  'Startled_mit052Trial-8Click-21.mat',
#  'Alarmed_mit052Trial-10Click-22.mat',
#  'Sad_mit052Trial-10Click-24.mat',
#  'Disgust_mit052Trial-10Click-23.mat',
#  'Angry_mit052Trial-10Click-25.mat',
#  'Lust_mit052Trial-11Click-28.mat',
#  'Lust_mit052Trial-11Click-27.mat',
#  'Aroused_mit052Trial-11Click-26.mat',
#  'Hate_mit054Trial-6Click-3.mat',
#  'Afraid_mit054Trial-4Click-1.mat',
#  'Afraid_mit054Trial-6Click-4.mat',
#  'Afraid_mit054Trial-9Click-6.mat',
#  'Afraid_mit054Trial-7Click-5.mat',
#  'Frustrated_mit054Trial-10Click-7.mat',
#  'Happy_mit061Trial-3Click-2.mat',
#  'Adventorous_mit061Trial-3Click-3.mat',
#  'Happy_mit061Trial-4Click-5.mat',
#  'Aroused_mit061Trial-4Click-4.mat',
#  'Aroused_mit061Trial-4Click-6.mat',
#  'Afraid_mit061Trial-5Click-7.mat',
#  'Joyous_mit061Trial-8Click-8.mat',
#  'Sad_mit061Trial-10Click-9.mat',
#  'Excited_mit061Trial-11Click-10.mat',
#  'Angry_mit067Trial-1Click-1.mat',
#  'Distress_mit067Trial-4Click-3.mat',
#  'Distress_mit067Trial-4Click-2.mat',
#  'Joyous_mit067Trial-8Click-5.mat',
#  'Angry_mit067Trial-9Click-6.mat',
#  'Angry_mit067Trial-6Click-4.mat',
#  'Hate_mit067Trial-10Click-7.mat',
#  'Adventorous_mit072Trial-1Click-1.mat',
#  'Alarmed_mit072Trial-1Click-2.mat',
#  'Happy_mit072Trial-2Click-4.mat',
#  'Adventorous_mit072Trial-1Click-3.mat',
#  'Joyous_mit072Trial-2Click-5.mat',
#  'Amused_mit072Trial-2Click-6.mat',
#  'Startled_mit072Trial-3Click-9.mat',
#  'Disgust_mit072Trial-3Click-8.mat',
#  'Joyous_mit072Trial-2Click-7.mat',
#  'Afraid_mit072Trial-3Click-11.mat',
#  'Angry_mit072Trial-3Click-10.mat',
#  'Alarmed_mit072Trial-3Click-12.mat',
#  'Despondent_mit072Trial-4Click-14.mat',
#  'Sad_mit072Trial-4Click-13.mat',
#  'Sad_mit072Trial-4Click-15.mat',
#  'Miserable_mit072Trial-4Click-16.mat',
#  'Alarmed_mit072Trial-5Click-17.mat',
#  'Afraid_mit072Trial-5Click-18.mat',
#  'Happy_mit072Trial-6Click-19.mat',
#  'Angry_mit072Trial-7Click-21.mat',
#  'Joyous_mit072Trial-6Click-20.mat',
#  'Distress_mit072Trial-7Click-23.mat',
#  'Disgust_mit072Trial-7Click-22.mat',
#  'Hate_mit072Trial-7Click-24.mat',
#  'Delighted_mit072Trial-9Click-26.mat',
#  'Excited_mit072Trial-9Click-25.mat',
#  'Adventorous_mit072Trial-10Click-27.mat',
#  'Excited_mit072Trial-10Click-28.mat',
#  'Adventorous_mit072Trial-10Click-29.mat',
#  'Alarmed_mit072Trial-11Click-31.mat',
#  'Angry_mit072Trial-11Click-30.mat',
#  'Despondent_mit072Trial-11Click-32.mat',
#  'Excited_mit074Trial-3Click-1.mat',
#  'Passionate_mit074Trial-3Click-2.mat',
#  'Adventorous_mit074Trial-5Click-5.mat',
#  'Adventorous_mit074Trial-5Click-4.mat',
#  'Alarmed_mit074Trial-5Click-3.mat',
#  'Hate_mit074Trial-6Click-7.mat',
#  'Disgust_mit074Trial-7Click-8.mat',
#  'Disgust_mit074Trial-6Click-6.mat',
#  'Hate_mit074Trial-7Click-9.mat',
#  'Disgust_mit074Trial-7Click-10.mat',
#  'Disgust_mit074Trial-8Click-11.mat',
#  'Hate_mit074Trial-8Click-12.mat',
#  'Despondent_mit074Trial-9Click-15.mat',
#  'Sad_mit074Trial-9Click-13.mat',
#  'Depressed_mit074Trial-9Click-14.mat',
#  'Disgust_mit074Trial-10Click-17.mat',
#  'Miserable_mit074Trial-10Click-18.mat',
#  'Hate_mit074Trial-10Click-16.mat',
#  'Disgust_mit074Trial-10Click-19.mat',
#  'Afraid_mit076Trial-4Click-4.mat',
#  'Afraid_mit076Trial-4Click-3.mat',
#  'Taken Aback_mit076Trial-4Click-2.mat',
#  'Melancholic_mit076Trial-8Click-5.mat',
#  'Startled_mit079Trial-1Click-1.mat',
#  'Distress_mit079Trial-1Click-3.mat',
#  'Distress_mit079Trial-1Click-2.mat',
#  'Frustrated_mit079Trial-2Click-4.mat',
#  'Triumphant_mit079Trial-3Click-8.mat',
#  'Delighted_mit079Trial-3Click-7.mat',
#  'Passionate_mit079Trial-5Click-9.mat',
#  'Lust_mit079Trial-5Click-10.mat',
#  'Delighted_mit079Trial-6Click-11.mat',
#  'Startled_mit079Trial-6Click-12.mat',
#  'Afraid_mit079Trial-6Click-13.mat',
#  'Tense_mit079Trial-7Click-14.mat',
#  'Afraid_mit079Trial-7Click-15.mat',
#  'Tense_mit079Trial-7Click-16.mat',
#  'Excited_mit079Trial-8Click-17.mat',
#  'Distress_mit079Trial-8Click-19.mat',
#  'Distress_mit079Trial-8Click-18.mat',
#  'Startled_mit079Trial-8Click-20.mat',
#  'Excited_mit079Trial-9Click-22.mat',
#  'Excited_mit079Trial-9Click-21.mat',
#  'Amused_mit079Trial-9Click-23.mat',
#  'Distress_mit079Trial-10Click-25.mat',
#  'Disgust_mit079Trial-10Click-24.mat',
#  'Disgust_mit079Trial-10Click-27.mat',
#  'Angry_mit079Trial-10Click-26.mat',
#  'Afraid_mit080Trial-2Click-1.mat',
#  'Afraid_mit080Trial-2Click-2.mat',
#  'Passionate_mit080Trial-3Click-3.mat',
#  'Disgust_mit080Trial-7Click-5.mat',
#  'Frustrated_mit080Trial-7Click-6.mat',
#  'Distress_mit080Trial-6Click-4.mat',
#  'Disgust_mit080Trial-11Click-7.mat',
#  'Sad_mit081Trial-3Click-1.mat',
#  'Happy_mit081Trial-7Click-3.mat',
#  'Afraid_mit081Trial-10Click-7.mat',
#  'Startled_mit081Trial-9Click-4.mat',
#  'Taken Aback_mit082Trial-1Click-1.mat',
#  'Afraid_mit082Trial-2Click-2.mat',
#  'Delighted_mit082Trial-3Click-4.mat',
#  'Tense_mit082Trial-2Click-3.mat',
#  'Disgust_mit082Trial-4Click-6.mat',
#  'Amused_mit082Trial-3Click-5.mat',
#  'Afraid_mit082Trial-4Click-7.mat',
#  'Angry_mit082Trial-4Click-8.mat',
#  'Angry_mit082Trial-4Click-9.mat',
#  'Frustrated_mit082Trial-5Click-10.mat',
#  'Sad_mit082Trial-5Click-11.mat',
#  'Distrustful_mit082Trial-5Click-13.mat',
#  'Sad_mit082Trial-5Click-12.mat',
#  'Melancholic_mit082Trial-7Click-16.mat',
#  'Miserable_mit082Trial-7Click-15.mat',
#  'Dissatisfied_mit082Trial-7Click-14.mat',
#  'Delighted_mit082Trial-9Click-17.mat',
#  'Afraid_mit082Trial-10Click-19.mat',
#  'Aroused_mit082Trial-9Click-18.mat',
#  'Startled_mit082Trial-10Click-20.mat',
#  'Distress_mit082Trial-10Click-21.mat',
#  'Alarmed_mit082Trial-11Click-23.mat',
#  'Startled_mit082Trial-11Click-24.mat',
#  'Distress_mit082Trial-11Click-22.mat',
#  'Afraid_mit082Trial-11Click-25.mat',
#  'Love_mit096Trial-2Click-1.mat',
#  'Compassionate_mit096Trial-5Click-3.mat',
#  'Aroused_mit096Trial-2Click-2.mat',
#  'Angry_mit096Trial-8Click-6.mat',
#  'Tense_mit096Trial-6Click-5.mat',
#  'Compassionate_mit096Trial-5Click-4.mat',
#  'Excited_mit096Trial-9Click-7.mat',
#  'Excited_mit096Trial-11Click-9.mat',
#  'Adventorous_mit097Trial-1Click-1.mat',
#  'Alarmed_mit097Trial-2Click-2.mat',
#  'Alarmed_mit097Trial-2Click-3.mat',
#  'Distress_mit097Trial-5Click-6.mat',
#  'Miserable_mit097Trial-3Click-5.mat',
#  'Depressed_mit097Trial-3Click-4.mat',
#  'Sad_mit097Trial-10Click-8.mat',
#  'Disgust_mit097Trial-9Click-7.mat',
#  'Pleased_mit097Trial-11Click-9.mat',
#  'Disgust_mit099Trial-1Click-2.mat',
#  'Tense_mit099Trial-1Click-1.mat',
#  'Afraid_mit099Trial-2Click-5.mat',
#  'Afraid_mit099Trial-2Click-4.mat',
#  'Afraid_mit099Trial-2Click-3.mat',
#  'Alarmed_mit099Trial-3Click-7.mat',
#  'Miserable_mit099Trial-3Click-6.mat',
#  'Distress_mit099Trial-4Click-10.mat',
#  'Taken Aback_mit099Trial-4Click-9.mat',
#  'Alarmed_mit099Trial-3Click-8.mat',
#  'Hate_mit099Trial-4Click-11.mat',
#  'Miserable_mit099Trial-5Click-12.mat',
#  'Passionate_mit099Trial-6Click-14.mat',
#  'Lust_mit099Trial-6Click-15.mat',
#  'Alarmed_mit099Trial-5Click-13.mat',
#  'Sad_mit099Trial-7Click-16.mat',
#  'Amused_mit099Trial-9Click-17.mat',
#  'Excited_mit099Trial-9Click-18.mat',
#  'Afraid_mit099Trial-10Click-20.mat',
#  'Sad_mit099Trial-10Click-21.mat',
#  'Sad_mit099Trial-10Click-22.mat',
#  'Joyous_mit104Trial-2Click-1.mat',
#  'Excited_mit104Trial-9Click-2.mat',
#  'Adventorous_mit104Trial-9Click-4.mat',
#  'Joyous_mit104Trial-9Click-3.mat',
#  'Sad_mit104Trial-10Click-5.mat',
#  'Dissatisfied_mit106Trial-5Click-2.mat',
#  'Hate_mit106Trial-3Click-1.mat',
#  'Sad_mit106Trial-6Click-5.mat',
#  'Sad_mit106Trial-5Click-3.mat',
#  'Dissatisfied_mit106Trial-6Click-4.mat',
#  'Happy_mit106Trial-9Click-7.mat',
#  'Passionate_mit106Trial-9Click-6.mat',
#  'Angry_mit106Trial-10Click-9.mat',
#  'Angry_mit106Trial-10Click-8.mat',
#  'Sad_mit107Trial-3Click-1.mat',
#  'Afraid_mit107Trial-4Click-2.mat',
#  'Despondent_mit107Trial-7Click-4.mat',
#  'Adventorous_mit107Trial-6Click-3.mat',
#  'Angry_mit107Trial-10Click-5.mat',
#  'Tense_mit108Trial-5Click-1.mat',
#  'Angry_mit108Trial-5Click-2.mat',
#  'Afraid_mit108Trial-8Click-5.mat',
#  'Dissatisfied_mit108Trial-8Click-4.mat',
#  'Delighted_mit108Trial-7Click-3.mat',
#  'Alarmed_mit108Trial-9Click-6.mat',
#  'Afraid_mit108Trial-9Click-7.mat',
#  'Miserable_mit108Trial-10Click-8.mat',
#  'Delighted_mit111Trial-4Click-2.mat',
#  'Joyous_mit111Trial-4Click-1.mat',
#  'Adventorous_mit111Trial-6Click-4.mat',
#  'Happy_mit111Trial-4Click-3.mat',
#  'Excited_mit111Trial-6Click-5.mat',
#  'Sad_mit111Trial-7Click-7.mat',
#  'Depressed_mit111Trial-7Click-6.mat',
#  'Afraid_mit111Trial-9Click-8.mat',
#  'Sad_mit111Trial-10Click-9.mat',
#  'Angry_mit111Trial-10Click-10.mat',
#  'Hate_mit111Trial-10Click-11.mat',
#  'Disgust_mit113Trial-5Click-2.mat',
#  'Amused_mit113Trial-2Click-1.mat',
#  'Startled_mit113Trial-6Click-3.mat',
#  'Triumphant_mit113Trial-8Click-4.mat',
#  'Disgust_mit113Trial-9Click-5.mat',
#  'Happy_mit113Trial-10Click-6.mat',
#  'Depressed_mit113Trial-11Click-7.mat',
#  'Startled_mit114Trial-2Click-4.mat',
#  'Hopeful_mit114Trial-1Click-1.mat',
#  'Joyous_mit114Trial-3Click-6.mat',
#  'Joyous_mit114Trial-3Click-7.mat',
#  'Excited_mit114Trial-2Click-5.mat',
#  'Distress_mit114Trial-4Click-8.mat',
#  'Alarmed_mit114Trial-4Click-11.mat',
#  'Love_mit114Trial-5Click-12.mat',
#  'Compassionate_mit114Trial-4Click-10.mat',
#  'Startled_mit114Trial-5Click-13.mat',
#  'Hate_mit114Trial-5Click-14.mat',
#  'Tense_mit114Trial-6Click-15.mat',
#  'Afraid_mit114Trial-6Click-16.mat',
#  'Dissatisfied_mit114Trial-7Click-19.mat',
#  'Angry_mit114Trial-7Click-20.mat',
#  'Sad_mit114Trial-7Click-21.mat',
#  'Sad_mit114Trial-7Click-22.mat',
#  'Afraid_mit114Trial-8Click-24.mat',
#  'Sad_mit114Trial-8Click-25.mat',
#  'Afraid_mit114Trial-8Click-23.mat',
#  'Alarmed_mit114Trial-8Click-26.mat',
#  'Afraid_mit114Trial-10Click-30.mat',
#  'Amused_mit114Trial-10Click-29.mat',
#  'Passionate_mit114Trial-11Click-32.mat',
#  'Adventorous_mit114Trial-10Click-31.mat',
#  'Lust_mit114Trial-11Click-34.mat',
#  'Lust_mit114Trial-11Click-33.mat',
#  'Pensive_mit116Trial-2Click-2.mat',
#  'Pensive_mit116Trial-2Click-1.mat',
#  'Joyous_mit116Trial-3Click-3.mat',
#  'Depressed_mit116Trial-6Click-5.mat',
#  'Sad_mit116Trial-4Click-4.mat',
#  'Sad_mit116Trial-6Click-6.mat',
#  'Miserable_mit116Trial-6Click-7.mat',
#  'Sad_mit116Trial-7Click-8.mat',
#  'Miserable_mit116Trial-9Click-9.mat',
#  'Dissatisfied_mit116Trial-9Click-10.mat',
#  'Excited_mit116Trial-10Click-12.mat',
#  'Taken Aback_mit116Trial-11Click-13.mat',
#  'Joyous_mit116Trial-10Click-11.mat',
#  'Distress_mit116Trial-11Click-14.mat',
#  'Joyous_mit117Trial-2Click-1.mat',
#  'Hate_mit117Trial-3Click-2.mat',
#  'Angry_mit117Trial-5Click-4.mat',
#  'Sad_mit117Trial-4Click-3.mat',
#  'Delighted_mit117Trial-10Click-5.mat',
#  'Distress_mit117Trial-11Click-6.mat',
#  'Excited_mit121Trial-1Click-1.mat',
#  'Joyous_mit121Trial-2Click-3.mat',
#  'Delighted_mit121Trial-2Click-2.mat',
#  'Sad_mit121Trial-3Click-4.mat',
#  'Taken Aback_mit121Trial-4Click-6.mat',
#  'Sad_mit121Trial-3Click-5.mat',
#  'Miserable_mit121Trial-4Click-8.mat',
#  'Miserable_mit121Trial-4Click-7.mat',
#  'Startled_mit121Trial-5Click-9.mat',
#  'Startled_mit121Trial-9Click-10.mat',
#  'Sad_mit121Trial-9Click-11.mat',
#  'Angry_mit121Trial-10Click-13.mat',
#  'Afraid_mit121Trial-11Click-14.mat',
#  'Angry_mit121Trial-10Click-12.mat',
#  'Alarmed_mit121Trial-11Click-15.mat',
#  'Amused_mit122Trial-1Click-1.mat',
#  'Miserable_mit122Trial-2Click-2.mat',
#  'Hate_mit122Trial-2Click-4.mat',
#  'Hate_mit122Trial-2Click-3.mat',
#  'Disgust_mit122Trial-3Click-6.mat',
#  'Afraid_mit122Trial-3Click-5.mat',
#  'Disgust_mit122Trial-4Click-7.mat',
#  'Angry_mit122Trial-6Click-9.mat',
#  'Hate_mit122Trial-6Click-8.mat',
#  'Afraid_mit122Trial-7Click-12.mat',
#  'Hate_mit122Trial-6Click-11.mat',
#  'Angry_mit122Trial-6Click-10.mat',
#  'Startled_mit122Trial-8Click-14.mat',
#  'Distress_mit122Trial-7Click-13.mat',
#  'Distress_mit122Trial-8Click-15.mat',
#  'Excited_mit122Trial-10Click-16.mat',
#  'Joyous_mit122Trial-11Click-17.mat',
#  'Happy_mit122Trial-11Click-18.mat',
#  'Afraid_mit123Trial-2Click-1.mat',
#  'Afraid_mit123Trial-2Click-2.mat',
#  'Taken Aback_mit123Trial-4Click-3.mat',
#  'Angry_mit123Trial-5Click-5.mat',
#  'Taken Aback_mit123Trial-4Click-4.mat',
#  'Angry_mit123Trial-5Click-6.mat',
#  'Alarmed_mit123Trial-8Click-8.mat',
#  'Tense_mit123Trial-8Click-7.mat',
#  'Alarmed_mit123Trial-9Click-10.mat',
#  'Alarmed_mit123Trial-9Click-9.mat',
#  'Melancholic_mitb2017007Trial-2Click-1.mat',
#  'Sad_mitb2017007Trial-6Click-3.mat',
#  'Sad_mitb2017007Trial-4Click-2.mat',
#  'Adventorous_mitb2017007Trial-7Click-4.mat',
#  'Excited_mitb2017007Trial-7Click-5.mat',
#  'Taken Aback_mitb2017007Trial-9Click-6.mat',
#  'Disgust_mitb2017007Trial-11Click-7.mat',
#  'Distrustful_mitb2017007Trial-11Click-8.mat']

# %%
rating = pd.read_csv('/content/drive/My Drive/MTech_Thesis/DENS/Rating/wholeFrequencyDependentDataWithVADLFR_ReFormattingWholeFrequencyVA - wholeFrequencyDependentDataWithVADLFR_ReFormattingWholeFrequencyVA.csv')

# %%
eeg_data = []
eeg_label = []

# %%
def label_mapping(valence, arousal):
    # HVHA, HVLA, LVHA, and LVLA
    
    if (valence > 5 and arousal > 5):
        label = 0 
    elif (valence > 5 and arousal <= 5):
        label = 1 
    elif (valence <= 5 and arousal > 5):
        label = 2 
    elif (valence <= 5 and arousal <= 5):
        label = 3
    
    return label

# %%
base_path = "/content/drive/My Drive/MTech_Thesis/DENS/Emotional/"
for f in files:
  if f.endswith(".mat"):
    file_str = f[:-4]
    df = rating[rating["Subject"].str.contains(file_str)]
    if not df.empty:
      path = base_path + f
      mat = sio.loadmat(path)
      data = mat.get('eegData')
      eeg_data.append(data)
      df = df[['Subject','valence','arousal']]
      df = df.drop_duplicates()
      valence = df['valence']
      arousal = df['arousal']
      lab = label_mapping(valence.values[0], arousal.values[0])
      eeg_label.append(lab)

# %%
eeg_data = np.array(eeg_data)

# %%
eeg_data.shape
# Out:
# (465, 128, 1751)

# %%
eeg_label = np.array(eeg_label)

# %%
eeg_label.shape
# Out:
# (465,)

# %%
eeg_Label = []
for i in eeg_label:
    for j in range (0,128):
        eeg_Label.append(i)

# %%
from tensorflow.keras.utils import to_categorical 
y = to_categorical(eeg_Label)

# %%
y.shape
# Out:
# (59520, 4)

# %%
import functools
def combine_dims(a, i=0, n=1):
  s = list(a.shape)
  combined = functools.reduce(lambda x,y: x*y, s[i:i+n+1])
  return np.reshape(a, s[:i] + [combined] + s[i+n+1:])

# %%
eeg_Data = combine_dims(np.array(eeg_data), 0)

# %%
eeg_Data.shape
# Out:
# (59520, 1751)

# %%
fs = 250

size_dataset = len(eeg_Data)
nperseg = 125
noverlap = 62
f_size = math.ceil(((nperseg + 1)/2))
t_size = int((eeg_Data[0].size - noverlap ) / (nperseg - noverlap))
X_full = np.ndarray(shape=(size_dataset, f_size, t_size, 3))                     
for i in range(0, size_dataset):
  for j in range(0,3):
    X = eeg_Data[i] 
    f, t, Sxx = spectrogram(X, fs, nperseg = nperseg, noverlap = noverlap, mode='psd')
    X_full[i, :, :, j] = Sxx

# %%
X_full = np.array(X_full)

# %%
X_full.shape
# Out:
# (59520, 63, 26, 3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_full, y, test_size=0.2, random_state=42)

# %%
X_train /= 255
X_test /= 255

# %%
num_classes = 4

# %%
input_shape = (X_train.shape[1],X_train.shape[2],X_train.shape[3])
input_shape
# Out:
# (63, 26, 3)

# %%
zero_weight = 0.95
one_weight = 8.94
two_weight = 0.48
three_weight = 1.35

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), 
          strides=(1, 1),
          activation='relu', 
          input_shape=input_shape))
model.add(MaxPooling2D((2, 2), strides=(2, 2)))

model.add(Conv2D(64, (3, 3), 
          activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.1))

model.add(Flatten())

model.add(RepeatVector(4))

model.add(LSTM(256, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(128))
model.add(Dropout(0.2))

model.add(Dense(64, activation="relu"))
model.add(Dropout(0.2))


model.add(Dense(num_classes, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 61, 24, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 30, 12, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 28, 10, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 5, 64)        0
#  2D)
#
#  dropout (Dropout)           (None, 14, 5, 64)         0
#
#  flatten (Flatten)           (None, 4480)              0
#
#  repeat_vector (RepeatVector  (None, 4, 4480)          0
#  )
#
#  lstm (LSTM)                 (None, 4, 256)            4850688
#
#  dropout_1 (Dropout)         (None, 4, 256)            0
#
#  lstm_1 (LSTM)               (None, 128)               197120
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 5,075,716
# Trainable params: 5,075,716
# Non-trainable params: 0
# _________________________________________________________________

# %%
'''
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))
'''
# Out:
# '\nfrom keras import backend as K\n\ndef recall_m(y_true, y_pred):\n    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))\n    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))\n    recall = true_positives / (possible_positives + K.epsilon())\n    return recall\n\ndef precision_m(y_true, y_pred):\n    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))\n    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))\n    precision = true_positives / (predicted_positives + K.epsilon())\n    return precision\n\ndef f1_m(y_true, y_pred):\n    precision = precision_m(y_true, y_pred)\n    recall = recall_m(y_true, y_pred)\n    return 2*((precision*recall)/(precision+recall+K.epsilon()))\n'

# %%
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
model.compile(optimizer ="Adam", loss =keras.losses.categorical_crossentropy, metrics=['accuracy'])
m=model.fit(X_train, y_train,epochs=100,batch_size=256,verbose=1,validation_data=(X_test, y_test), class_weight={0:zero_weight, 1:one_weight, 2: two_weight, 3:three_weight}, callbacks =[es, mc])
# Out:
# Epoch 1/100
# 186/186 [==============================] - ETA: 0s - loss: 1.3806 - accuracy: 0.2456
# Epoch 1: val_accuracy improved from -inf to 0.44951, saving model to best_model.h5
# 186/186 [==============================] - 35s 117ms/step - loss: 1.3806 - accuracy: 0.2456 - val_loss: 1.3540 - val_accuracy: 0.4495
# Epoch 2/100
# 184/186 [============================>.] - ETA: 0s - loss: 1.3326 - accuracy: 0.2713
# Epoch 2: val_accuracy did not improve from 0.44951
# 186/186 [==============================] - 3s 19ms/step - loss: 1.3317 - accuracy: 0.2710 - val_loss: 1.3112 - val_accuracy: 0.3135
# Epoch 3/100
# 184/186 [============================>.] - ETA: 0s - loss: 1.2449 - accuracy: 0.2954
# Epoch 3: val_accuracy did not improve from 0.44951
# 186/186 [==============================] - 3s 18ms/step - loss: 1.2443 - accuracy: 0.2961 - val_loss: 1.2516 - val_accuracy: 0.3923
# Epoch 4/100
# 183/186 [============================>.] - ETA: 0s - loss: 1.1494 - accuracy: 0.3834
# Epoch 4: val_accuracy improved from 0.44951 to 0.46858, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 1.1483 - accuracy: 0.3840 - val_loss: 1.1902 - val_accuracy: 0.4686
# Epoch 5/100
# 186/186 [==============================] - ETA: 0s - loss: 1.0801 - accuracy: 0.4238
# Epoch 5: val_accuracy improved from 0.46858 to 0.49294, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 1.0801 - accuracy: 0.4238 - val_loss: 1.0929 - val_accuracy: 0.4929
# Epoch 6/100
# 185/186 [============================>.] - ETA: 0s - loss: 1.0156 - accuracy: 0.4584
# Epoch 6: val_accuracy did not improve from 0.49294
# 186/186 [==============================] - 3s 18ms/step - loss: 1.0151 - accuracy: 0.4585 - val_loss: 1.1108 - val_accuracy: 0.4692
# Epoch 7/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.9645 - accuracy: 0.4850
# Epoch 7: val_accuracy did not improve from 0.49294
# 186/186 [==============================] - 3s 18ms/step - loss: 0.9640 - accuracy: 0.4848 - val_loss: 1.0126 - val_accuracy: 0.4854
# Epoch 8/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.9220 - accuracy: 0.5071
# Epoch 8: val_accuracy improved from 0.49294 to 0.54402, saving model to best_model.h5
# 186/186 [==============================] - 5s 25ms/step - loss: 0.9220 - accuracy: 0.5069 - val_loss: 0.9854 - val_accuracy: 0.5440
# Epoch 9/100
# 186/186 [==============================] - ETA: 0s - loss: 0.8614 - accuracy: 0.5312
# Epoch 9: val_accuracy improved from 0.54402 to 0.59064, saving model to best_model.h5
# 186/186 [==============================] - 4s 19ms/step - loss: 0.8614 - accuracy: 0.5312 - val_loss: 0.9145 - val_accuracy: 0.5906
# Epoch 10/100
# 186/186 [==============================] - ETA: 0s - loss: 0.8137 - accuracy: 0.5580
# Epoch 10: val_accuracy did not improve from 0.59064
# 186/186 [==============================] - 3s 19ms/step - loss: 0.8137 - accuracy: 0.5580 - val_loss: 0.9618 - val_accuracy: 0.5381
# Epoch 11/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.7826 - accuracy: 0.5730
# Epoch 11: val_accuracy improved from 0.59064 to 0.59577, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 0.7826 - accuracy: 0.5730 - val_loss: 0.8748 - val_accuracy: 0.5958
# Epoch 12/100
# 183/186 [============================>.] - ETA: 0s - loss: 0.7446 - accuracy: 0.5894
# Epoch 12: val_accuracy improved from 0.59577 to 0.62945, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 0.7439 - accuracy: 0.5900 - val_loss: 0.8261 - val_accuracy: 0.6295
# Epoch 13/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.6886 - accuracy: 0.6095
# Epoch 13: val_accuracy improved from 0.62945 to 0.64903, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 0.6892 - accuracy: 0.6095 - val_loss: 0.7640 - val_accuracy: 0.6490
# Epoch 14/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.6409 - accuracy: 0.6317
# Epoch 14: val_accuracy improved from 0.64903 to 0.68406, saving model to best_model.h5
# 186/186 [==============================] - 4s 19ms/step - loss: 0.6399 - accuracy: 0.6323 - val_loss: 0.7031 - val_accuracy: 0.6841
# Epoch 15/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.6122 - accuracy: 0.6501
# Epoch 15: val_accuracy improved from 0.68406 to 0.70439, saving model to best_model.h5
# 186/186 [==============================] - 4s 19ms/step - loss: 0.6123 - accuracy: 0.6502 - val_loss: 0.6691 - val_accuracy: 0.7044
# Epoch 16/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.5770 - accuracy: 0.6668
# Epoch 16: val_accuracy did not improve from 0.70439
# 186/186 [==============================] - 3s 19ms/step - loss: 0.5766 - accuracy: 0.6671 - val_loss: 0.6910 - val_accuracy: 0.6932
# Epoch 17/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.5503 - accuracy: 0.6784
# Epoch 17: val_accuracy did not improve from 0.70439
# 186/186 [==============================] - 3s 19ms/step - loss: 0.5503 - accuracy: 0.6782 - val_loss: 0.7396 - val_accuracy: 0.6780
# Epoch 18/100
# 183/186 [============================>.] - ETA: 0s - loss: 0.5277 - accuracy: 0.6937
# Epoch 18: val_accuracy did not improve from 0.70439
# 186/186 [==============================] - 3s 19ms/step - loss: 0.5273 - accuracy: 0.6943 - val_loss: 0.6627 - val_accuracy: 0.6987
# Epoch 19/100
# 183/186 [============================>.] - ETA: 0s - loss: 0.4921 - accuracy: 0.7169
# Epoch 19: val_accuracy improved from 0.70439 to 0.75193, saving model to best_model.h5
# 186/186 [==============================] - 4s 23ms/step - loss: 0.4911 - accuracy: 0.7168 - val_loss: 0.5681 - val_accuracy: 0.7519
# Epoch 20/100
# 186/186 [==============================] - ETA: 0s - loss: 0.4772 - accuracy: 0.7274
# Epoch 20: val_accuracy improved from 0.75193 to 0.76126, saving model to best_model.h5
# 186/186 [==============================] - 4s 19ms/step - loss: 0.4772 - accuracy: 0.7274 - val_loss: 0.5629 - val_accuracy: 0.7613
# Epoch 21/100
# 183/186 [============================>.] - ETA: 0s - loss: 0.4304 - accuracy: 0.7533
# Epoch 21: val_accuracy improved from 0.76126 to 0.78621, saving model to best_model.h5
# 186/186 [==============================] - 4s 19ms/step - loss: 0.4293 - accuracy: 0.7536 - val_loss: 0.5055 - val_accuracy: 0.7862
# Epoch 22/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.4003 - accuracy: 0.7714
# Epoch 22: val_accuracy did not improve from 0.78621
# 186/186 [==============================] - 3s 19ms/step - loss: 0.4002 - accuracy: 0.7713 - val_loss: 0.5099 - val_accuracy: 0.7834
# Epoch 23/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.3789 - accuracy: 0.7824
# Epoch 23: val_accuracy improved from 0.78621 to 0.81796, saving model to best_model.h5
# 186/186 [==============================] - 4s 19ms/step - loss: 0.3787 - accuracy: 0.7827 - val_loss: 0.4459 - val_accuracy: 0.8180
# Epoch 24/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.3432 - accuracy: 0.8031
# Epoch 24: val_accuracy did not improve from 0.81796
# 186/186 [==============================] - 3s 19ms/step - loss: 0.3431 - accuracy: 0.8032 - val_loss: 0.5289 - val_accuracy: 0.7721
# Epoch 25/100
# 183/186 [============================>.] - ETA: 0s - loss: 0.3320 - accuracy: 0.8122
# Epoch 25: val_accuracy did not improve from 0.81796
# 186/186 [==============================] - 3s 19ms/step - loss: 0.3322 - accuracy: 0.8121 - val_loss: 0.4503 - val_accuracy: 0.8115
# Epoch 26/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.3195 - accuracy: 0.8204
# Epoch 26: val_accuracy improved from 0.81796 to 0.82443, saving model to best_model.h5
# 186/186 [==============================] - 4s 22ms/step - loss: 0.3199 - accuracy: 0.8200 - val_loss: 0.4264 - val_accuracy: 0.8244
# Epoch 27/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.2901 - accuracy: 0.8395
# Epoch 27: val_accuracy improved from 0.82443 to 0.82502, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 0.2902 - accuracy: 0.8393 - val_loss: 0.4124 - val_accuracy: 0.8250
# Epoch 28/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.2834 - accuracy: 0.8408
# Epoch 28: val_accuracy improved from 0.82502 to 0.84644, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 0.2834 - accuracy: 0.8408 - val_loss: 0.3738 - val_accuracy: 0.8464
# Epoch 29/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.2532 - accuracy: 0.8569
# Epoch 29: val_accuracy improved from 0.84644 to 0.87525, saving model to best_model.h5
# 186/186 [==============================] - 4s 19ms/step - loss: 0.2530 - accuracy: 0.8569 - val_loss: 0.3273 - val_accuracy: 0.8753
# Epoch 30/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.2307 - accuracy: 0.8719
# Epoch 30: val_accuracy did not improve from 0.87525
# 186/186 [==============================] - 3s 18ms/step - loss: 0.2308 - accuracy: 0.8720 - val_loss: 0.3774 - val_accuracy: 0.8469
# Epoch 31/100
# 183/186 [============================>.] - ETA: 0s - loss: 0.2334 - accuracy: 0.8702
# Epoch 31: val_accuracy did not improve from 0.87525
# 186/186 [==============================] - 3s 19ms/step - loss: 0.2331 - accuracy: 0.8703 - val_loss: 0.3456 - val_accuracy: 0.8669
# Epoch 32/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.2172 - accuracy: 0.8795
# Epoch 32: val_accuracy did not improve from 0.87525
# 186/186 [==============================] - 4s 20ms/step - loss: 0.2173 - accuracy: 0.8793 - val_loss: 0.3319 - val_accuracy: 0.8715
# Epoch 33/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.2026 - accuracy: 0.8888
# Epoch 33: val_accuracy did not improve from 0.87525
# 186/186 [==============================] - 3s 19ms/step - loss: 0.2024 - accuracy: 0.8887 - val_loss: 0.3206 - val_accuracy: 0.8738
# Epoch 34/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.1780 - accuracy: 0.9017
# Epoch 34: val_accuracy improved from 0.87525 to 0.88676, saving model to best_model.h5
# 186/186 [==============================] - 4s 23ms/step - loss: 0.1778 - accuracy: 0.9018 - val_loss: 0.3003 - val_accuracy: 0.8868
# Epoch 35/100
# 186/186 [==============================] - ETA: 0s - loss: 0.1669 - accuracy: 0.9069
# Epoch 35: val_accuracy improved from 0.88676 to 0.90986, saving model to best_model.h5
# 186/186 [==============================] - 4s 19ms/step - loss: 0.1669 - accuracy: 0.9069 - val_loss: 0.2528 - val_accuracy: 0.9099
# Epoch 36/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.1549 - accuracy: 0.9153
# Epoch 36: val_accuracy did not improve from 0.90986
# 186/186 [==============================] - 3s 19ms/step - loss: 0.1551 - accuracy: 0.9153 - val_loss: 0.2548 - val_accuracy: 0.9055
# Epoch 37/100
# 183/186 [============================>.] - ETA: 0s - loss: 0.1402 - accuracy: 0.9238
# Epoch 37: val_accuracy improved from 0.90986 to 0.91935, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 0.1399 - accuracy: 0.9237 - val_loss: 0.2310 - val_accuracy: 0.9194
# Epoch 38/100
# 183/186 [============================>.] - ETA: 0s - loss: 0.1317 - accuracy: 0.9268
# Epoch 38: val_accuracy did not improve from 0.91935
# 186/186 [==============================] - 3s 19ms/step - loss: 0.1316 - accuracy: 0.9270 - val_loss: 0.2439 - val_accuracy: 0.9110
# Epoch 39/100
# 183/186 [============================>.] - ETA: 0s - loss: 0.1342 - accuracy: 0.9277
# Epoch 39: val_accuracy improved from 0.91935 to 0.92129, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 0.1344 - accuracy: 0.9279 - val_loss: 0.2298 - val_accuracy: 0.9213
# Epoch 40/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.1319 - accuracy: 0.9283
# Epoch 40: val_accuracy did not improve from 0.92129
# 186/186 [==============================] - 3s 19ms/step - loss: 0.1324 - accuracy: 0.9280 - val_loss: 0.2766 - val_accuracy: 0.8971
# Epoch 41/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.1116 - accuracy: 0.9382
# Epoch 41: val_accuracy did not improve from 0.92129
# 186/186 [==============================] - 3s 18ms/step - loss: 0.1120 - accuracy: 0.9382 - val_loss: 0.3006 - val_accuracy: 0.8944
# Epoch 42/100
# 186/186 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9426
# Epoch 42: val_accuracy improved from 0.92129 to 0.92750, saving model to best_model.h5
# 186/186 [==============================] - 4s 22ms/step - loss: 0.1046 - accuracy: 0.9426 - val_loss: 0.2069 - val_accuracy: 0.9275
# Epoch 43/100
# 186/186 [==============================] - ETA: 0s - loss: 0.1023 - accuracy: 0.9459
# Epoch 43: val_accuracy improved from 0.92750 to 0.93532, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 0.1023 - accuracy: 0.9459 - val_loss: 0.1954 - val_accuracy: 0.9353
# Epoch 44/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0833 - accuracy: 0.9539
# Epoch 44: val_accuracy improved from 0.93532 to 0.93632, saving model to best_model.h5
# 186/186 [==============================] - 4s 19ms/step - loss: 0.0833 - accuracy: 0.9539 - val_loss: 0.2024 - val_accuracy: 0.9363
# Epoch 45/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0848 - accuracy: 0.9536
# Epoch 45: val_accuracy did not improve from 0.93632
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0851 - accuracy: 0.9534 - val_loss: 0.2538 - val_accuracy: 0.9122
# Epoch 46/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.1055 - accuracy: 0.9459
# Epoch 46: val_accuracy did not improve from 0.93632
# 186/186 [==============================] - 3s 19ms/step - loss: 0.1053 - accuracy: 0.9459 - val_loss: 0.1958 - val_accuracy: 0.9351
# Epoch 47/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0745 - accuracy: 0.9613
# Epoch 47: val_accuracy improved from 0.93632 to 0.94061, saving model to best_model.h5
# 186/186 [==============================] - 4s 23ms/step - loss: 0.0745 - accuracy: 0.9613 - val_loss: 0.1882 - val_accuracy: 0.9406
# Epoch 48/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0659 - accuracy: 0.9644
# Epoch 48: val_accuracy did not improve from 0.94061
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0662 - accuracy: 0.9643 - val_loss: 0.2133 - val_accuracy: 0.9295
# Epoch 49/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0642 - accuracy: 0.9642
# Epoch 49: val_accuracy did not improve from 0.94061
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0640 - accuracy: 0.9643 - val_loss: 0.2006 - val_accuracy: 0.9402
# Epoch 50/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0819 - accuracy: 0.9596
# Epoch 50: val_accuracy improved from 0.94061 to 0.94178, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 0.0817 - accuracy: 0.9597 - val_loss: 0.1821 - val_accuracy: 0.9418
# Epoch 51/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0595 - accuracy: 0.9685
# Epoch 51: val_accuracy did not improve from 0.94178
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0594 - accuracy: 0.9685 - val_loss: 0.2070 - val_accuracy: 0.9388
# Epoch 52/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9706
# Epoch 52: val_accuracy improved from 0.94178 to 0.94271, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 0.0548 - accuracy: 0.9706 - val_loss: 0.1838 - val_accuracy: 0.9427
# Epoch 53/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0745 - accuracy: 0.9635
# Epoch 53: val_accuracy did not improve from 0.94271
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0745 - accuracy: 0.9635 - val_loss: 0.2122 - val_accuracy: 0.9297
# Epoch 54/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9723
# Epoch 54: val_accuracy did not improve from 0.94271
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0540 - accuracy: 0.9723 - val_loss: 0.1956 - val_accuracy: 0.9403
# Epoch 55/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0667 - accuracy: 0.9649
# Epoch 55: val_accuracy improved from 0.94271 to 0.94834, saving model to best_model.h5
# 186/186 [==============================] - 4s 23ms/step - loss: 0.0668 - accuracy: 0.9649 - val_loss: 0.1761 - val_accuracy: 0.9483
# Epoch 56/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0422 - accuracy: 0.9773
# Epoch 56: val_accuracy did not improve from 0.94834
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0422 - accuracy: 0.9773 - val_loss: 0.1857 - val_accuracy: 0.9483
# Epoch 57/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0397 - accuracy: 0.9792
# Epoch 57: val_accuracy improved from 0.94834 to 0.95086, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 0.0398 - accuracy: 0.9792 - val_loss: 0.1621 - val_accuracy: 0.9509
# Epoch 58/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9810
# Epoch 58: val_accuracy improved from 0.95086 to 0.95203, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 0.0360 - accuracy: 0.9810 - val_loss: 0.1780 - val_accuracy: 0.9520
# Epoch 59/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0423 - accuracy: 0.9783
# Epoch 59: val_accuracy did not improve from 0.95203
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0424 - accuracy: 0.9783 - val_loss: 0.1872 - val_accuracy: 0.9502
# Epoch 60/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0421 - accuracy: 0.9783
# Epoch 60: val_accuracy did not improve from 0.95203
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0420 - accuracy: 0.9783 - val_loss: 0.1860 - val_accuracy: 0.9510
# Epoch 61/100
# 183/186 [============================>.] - ETA: 0s - loss: 0.0331 - accuracy: 0.9829
# Epoch 61: val_accuracy did not improve from 0.95203
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0333 - accuracy: 0.9828 - val_loss: 0.1945 - val_accuracy: 0.9500
# Epoch 62/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0787 - accuracy: 0.9651
# Epoch 62: val_accuracy did not improve from 0.95203
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0786 - accuracy: 0.9652 - val_loss: 0.1730 - val_accuracy: 0.9511
# Epoch 63/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0299 - accuracy: 0.9848
# Epoch 63: val_accuracy improved from 0.95203 to 0.95615, saving model to best_model.h5
# 186/186 [==============================] - 4s 23ms/step - loss: 0.0298 - accuracy: 0.9848 - val_loss: 0.1800 - val_accuracy: 0.9561
# Epoch 64/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0351 - accuracy: 0.9827
# Epoch 64: val_accuracy did not improve from 0.95615
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0355 - accuracy: 0.9826 - val_loss: 0.1652 - val_accuracy: 0.9543
# Epoch 65/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0265 - accuracy: 0.9859
# Epoch 65: val_accuracy did not improve from 0.95615
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0264 - accuracy: 0.9859 - val_loss: 0.1736 - val_accuracy: 0.9542
# Epoch 66/100
# 183/186 [============================>.] - ETA: 0s - loss: 0.0378 - accuracy: 0.9819
# Epoch 66: val_accuracy did not improve from 0.95615
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0378 - accuracy: 0.9817 - val_loss: 0.1784 - val_accuracy: 0.9518
# Epoch 67/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0238 - accuracy: 0.9883
# Epoch 67: val_accuracy did not improve from 0.95615
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0238 - accuracy: 0.9883 - val_loss: 0.1736 - val_accuracy: 0.9556
# Epoch 68/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0749 - accuracy: 0.9659
# Epoch 68: val_accuracy did not improve from 0.95615
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0751 - accuracy: 0.9659 - val_loss: 0.1844 - val_accuracy: 0.9374
# Epoch 69/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0379 - accuracy: 0.9815
# Epoch 69: val_accuracy did not improve from 0.95615
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0379 - accuracy: 0.9815 - val_loss: 0.1842 - val_accuracy: 0.9514
# Epoch 70/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9886
# Epoch 70: val_accuracy improved from 0.95615 to 0.95707, saving model to best_model.h5
# 186/186 [==============================] - 4s 23ms/step - loss: 0.0217 - accuracy: 0.9886 - val_loss: 0.1787 - val_accuracy: 0.9571
# Epoch 71/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0316 - accuracy: 0.9848
# Epoch 71: val_accuracy did not improve from 0.95707
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0318 - accuracy: 0.9846 - val_loss: 0.2040 - val_accuracy: 0.9372
# Epoch 72/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0345 - accuracy: 0.9832
# Epoch 72: val_accuracy did not improve from 0.95707
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0345 - accuracy: 0.9832 - val_loss: 0.1873 - val_accuracy: 0.9455
# Epoch 73/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0201 - accuracy: 0.9900
# Epoch 73: val_accuracy improved from 0.95707 to 0.95867, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 0.0201 - accuracy: 0.9900 - val_loss: 0.1713 - val_accuracy: 0.9587
# Epoch 74/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0192 - accuracy: 0.9914
# Epoch 74: val_accuracy did not improve from 0.95867
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0192 - accuracy: 0.9913 - val_loss: 0.1748 - val_accuracy: 0.9492
# Epoch 75/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 0.9894
# Epoch 75: val_accuracy did not improve from 0.95867
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0223 - accuracy: 0.9893 - val_loss: 0.1693 - val_accuracy: 0.9550
# Epoch 76/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0165 - accuracy: 0.9916
# Epoch 76: val_accuracy did not improve from 0.95867
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0165 - accuracy: 0.9915 - val_loss: 0.1727 - val_accuracy: 0.9580
# Epoch 77/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9923
# Epoch 77: val_accuracy did not improve from 0.95867
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0158 - accuracy: 0.9923 - val_loss: 0.1755 - val_accuracy: 0.9567
# Epoch 78/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9856
# Epoch 78: val_accuracy did not improve from 0.95867
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0305 - accuracy: 0.9856 - val_loss: 0.1607 - val_accuracy: 0.9577
# Epoch 79/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9906
# Epoch 79: val_accuracy did not improve from 0.95867
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0203 - accuracy: 0.9906 - val_loss: 0.1694 - val_accuracy: 0.9547
# Epoch 80/100
# 183/186 [============================>.] - ETA: 0s - loss: 0.0314 - accuracy: 0.9860
# Epoch 80: val_accuracy improved from 0.95867 to 0.96001, saving model to best_model.h5
# 186/186 [==============================] - 4s 23ms/step - loss: 0.0311 - accuracy: 0.9861 - val_loss: 0.1620 - val_accuracy: 0.9600
# Epoch 81/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0155 - accuracy: 0.9923
# Epoch 81: val_accuracy did not improve from 0.96001
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0155 - accuracy: 0.9923 - val_loss: 0.1725 - val_accuracy: 0.9580
# Epoch 82/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0151 - accuracy: 0.9924
# Epoch 82: val_accuracy did not improve from 0.96001
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0150 - accuracy: 0.9925 - val_loss: 0.1615 - val_accuracy: 0.9600
# Epoch 83/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0145 - accuracy: 0.9927
# Epoch 83: val_accuracy did not improve from 0.96001
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0145 - accuracy: 0.9928 - val_loss: 0.1644 - val_accuracy: 0.9596
# Epoch 84/100
# 183/186 [============================>.] - ETA: 0s - loss: 0.0141 - accuracy: 0.9931
# Epoch 84: val_accuracy did not improve from 0.96001
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0141 - accuracy: 0.9931 - val_loss: 0.1889 - val_accuracy: 0.9563
# Epoch 85/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0182 - accuracy: 0.9916
# Epoch 85: val_accuracy did not improve from 0.96001
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0182 - accuracy: 0.9916 - val_loss: 0.1711 - val_accuracy: 0.9556
# Epoch 86/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9929
# Epoch 86: val_accuracy did not improve from 0.96001
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0155 - accuracy: 0.9929 - val_loss: 0.1815 - val_accuracy: 0.9588
# Epoch 87/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0387 - accuracy: 0.9842
# Epoch 87: val_accuracy did not improve from 0.96001
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0386 - accuracy: 0.9843 - val_loss: 0.1559 - val_accuracy: 0.9525
# Epoch 88/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9891
# Epoch 88: val_accuracy improved from 0.96001 to 0.96102, saving model to best_model.h5
# 186/186 [==============================] - 4s 23ms/step - loss: 0.0232 - accuracy: 0.9891 - val_loss: 0.1506 - val_accuracy: 0.9610
# Epoch 89/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0136 - accuracy: 0.9936
# Epoch 89: val_accuracy improved from 0.96102 to 0.96346, saving model to best_model.h5
# 186/186 [==============================] - 4s 19ms/step - loss: 0.0135 - accuracy: 0.9937 - val_loss: 0.1597 - val_accuracy: 0.9635
# Epoch 90/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9914
# Epoch 90: val_accuracy did not improve from 0.96346
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0198 - accuracy: 0.9914 - val_loss: 0.1655 - val_accuracy: 0.9604
# Epoch 91/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9934
# Epoch 91: val_accuracy did not improve from 0.96346
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0163 - accuracy: 0.9934 - val_loss: 0.2603 - val_accuracy: 0.9366
# Epoch 92/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0179 - accuracy: 0.9916
# Epoch 92: val_accuracy improved from 0.96346 to 0.96363, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 0.0179 - accuracy: 0.9916 - val_loss: 0.1672 - val_accuracy: 0.9636
# Epoch 93/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0111 - accuracy: 0.9949
# Epoch 93: val_accuracy improved from 0.96363 to 0.96463, saving model to best_model.h5
# 186/186 [==============================] - 4s 19ms/step - loss: 0.0110 - accuracy: 0.9949 - val_loss: 0.1572 - val_accuracy: 0.9646
# Epoch 94/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 0.9950
# Epoch 94: val_accuracy improved from 0.96463 to 0.96564, saving model to best_model.h5
# 186/186 [==============================] - 4s 20ms/step - loss: 0.0106 - accuracy: 0.9950 - val_loss: 0.1642 - val_accuracy: 0.9656
# Epoch 95/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9908
# Epoch 95: val_accuracy did not improve from 0.96564
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0217 - accuracy: 0.9908 - val_loss: 0.1674 - val_accuracy: 0.9492
# Epoch 96/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0141 - accuracy: 0.9934
# Epoch 96: val_accuracy did not improve from 0.96564
# 186/186 [==============================] - 3s 18ms/step - loss: 0.0141 - accuracy: 0.9934 - val_loss: 0.1528 - val_accuracy: 0.9631
# Epoch 97/100
# 185/186 [============================>.] - ETA: 0s - loss: 0.0184 - accuracy: 0.9913
# Epoch 97: val_accuracy did not improve from 0.96564
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0184 - accuracy: 0.9913 - val_loss: 0.1573 - val_accuracy: 0.9618
# Epoch 98/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0096 - accuracy: 0.9954
# Epoch 98: val_accuracy did not improve from 0.96564
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0096 - accuracy: 0.9954 - val_loss: 0.1565 - val_accuracy: 0.9620
# Epoch 99/100
# 186/186 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9972
# Epoch 99: val_accuracy did not improve from 0.96564
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0065 - accuracy: 0.9972 - val_loss: 0.1693 - val_accuracy: 0.9645
# Epoch 100/100
# 184/186 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 0.9947
# Epoch 100: val_accuracy did not improve from 0.96564
# 186/186 [==============================] - 3s 19ms/step - loss: 0.0113 - accuracy: 0.9947 - val_loss: 0.1699 - val_accuracy: 0.9579

# %%
saved_model = load_model('best_model.h5')

# %%
_, train_f1 = saved_model.evaluate(X_train, y_train, verbose=0)
_, test_f1 = saved_model.evaluate(X_test, y_test, verbose=0)

# %%
print(test_f1)
# Out:
# 0.9656417965888977

# %%
y_pred_saved = saved_model.predict(X_test)

# %%
print(y_pred_saved.shape)
# Out:
# (11904, 4)

# %%
import matplotlib.pyplot as plt
plt.plot(m.history['accuracy'])
plt.plot(m.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
y_test1=np.argmax(y_test, axis=1)
y_pred_saved=np.argmax(y_pred_saved,axis=1)

# %%
f_score = f1_score(y_test1,y_pred_saved, average = 'weighted')

# %%
print(f_score)
# Out:
# 0.9656256366883784

# %%
cf_matrix=confusion_matrix(y_test1, y_pred_saved)

# %%
#!pip install pretty-confusion-matrix

# %%
#from pretty_confusion_matrix import pp_matrix

# %%
#type(cf_matrix)

# %%
#cf_matrix

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
from matplotlib.collections import QuadMesh


def get_new_fig(fn, figsize=[8, 8]):
    """Init graphics"""
    fig1 = plt.figure(fn, figsize)
    ax1 = fig1.gca()  # Get Current Axis
    ax1.cla()  # clear existing plot
    return fig1, ax1


def configcell_text_and_colors(
    array_df, lin, col, oText, facecolors, posi, fz, fmt, show_null_values=0
):
    """
    config cell text and colors
    and return text elements to add and to dell
    @TODO: use fmt
    """
    text_add = []
    text_del = []
    cell_val = array_df[lin][col]
    tot_all = array_df[-1][-1]
    per = (float(cell_val) / tot_all) * 100
    curr_column = array_df[:, col]
    ccl = len(curr_column)
    
    # last line  and/or last column
    if (col == (ccl - 1)) or (lin == (ccl - 1)):
        # tots and percents
        if cell_val != 0:
            if (col == ccl - 1) and (lin == ccl - 1):
                tot_rig = 0
                for i in range(array_df.shape[0] - 1):
                    tot_rig += array_df[i][i]
                per_ok = (float(tot_rig) / cell_val) * 100
            elif col == ccl - 1:
                tot_rig = array_df[lin][lin]
                per_ok = (float(tot_rig) / cell_val) * 100
            
            elif lin == ccl - 1:
                tot_rig = array_df[col][col]
                per_ok = (float(tot_rig) / cell_val) * 100
            #per_err = 100 - per_ok
            
        else:
            per_ok = 0
            #per_ok = per_err = 0
            

        per_ok_s = ["%.2f%%" % (per_ok), "100%"][per_ok == 100]

        # text to DEL
        text_del.append(oText)

        # text to ADD
        font_prop = fm.FontProperties(weight="bold", size=22)
        text_kwargs = dict(
            color="w",
            ha="center",
            va="center",
            gid="sum",
            fontproperties=font_prop,
        )
        #lis_txt = ["%d" % (cell_val), per_ok_s, "%.2f%%" % (per_err)]
        lis_txt = ["%d" % (cell_val), per_ok_s]
        lis_kwa = [text_kwargs]
        dic = text_kwargs.copy()
        dic["color"] = "w"
        lis_kwa.append(dic)
        dic = text_kwargs.copy()
        dic["color"] = "w"
        lis_kwa.append(dic)
        '''
        lis_pos = [
            (oText._x, oText._y - 0.3),
            (oText._x, oText._y),
            (oText._x, oText._y + 0.3),
        ]
        '''
        lis_pos = [
            (oText._x, oText._y - 0.1),
            (oText._x, oText._y + 0.1),
        ]
        for i in range(len(lis_txt)):
            newText = dict(
                x=lis_pos[i][0],
                y=lis_pos[i][1],
                text=lis_txt[i],
                kw=lis_kwa[i],
            )
            text_add.append(newText)

        # set background color for sum cells (last line and last column)
        carr = [0.27, 0.30, 0.27, 1.0]
        if (col == ccl - 1) and (lin == ccl - 1):
            carr = [0.17, 0.20, 0.17, 1.0]
        facecolors[posi] = carr

    else:
        if per > 0:
            txt = "%s\n%.2f%%" % (cell_val, per)
        else:
            if show_null_values == 0:
                txt = "0\n0.0%"
            elif show_null_values == 1:
                txt = "0"
            else:
                txt = "0\n0.0%"
        oText.set_text(txt)

        # main diagonal
        if col == lin:
            # set color of the textin the diagonal to white
            oText.set_color("w")
            # set background color in the diagonal to blue
            facecolors[posi] = [0.35, 0.8, 0.55, 1.0]
        else:
            oText.set_color("r")

    return text_add, text_del


def insert_totals(df_cm):
    """insert total column and line (the last ones)"""
    sum_col = []
    for c in df_cm.columns:
        sum_col.append(df_cm[c].sum())
    sum_lin = []
    for item_line in df_cm.iterrows():
        sum_lin.append(item_line[1].sum())
    df_cm["sum_lin"] = sum_lin
    sum_col.append(np.sum(sum_lin))
    df_cm.loc["sum_col"] = sum_col


def pp_matrix_tej(
    df_cm,
    annot=True,
    cmap="Oranges",
    fmt=".2f",
    fz=22,
    lw=0.5,
    cbar=False,
    figsize=[12, 12],
    show_null_values=0,
    pred_val_axis="y",
):
    """
    print conf matrix with default layout (like matlab)
    params:
      df_cm          dataframe (pandas) without totals
      annot          print text in each cell
      cmap           Oranges,Oranges_r,YlGnBu,Blues,RdBu, ... see:
      fz             fontsize
      lw             linewidth
      pred_val_axis  where to show the prediction values (x or y axis)
                      'col' or 'x': show predicted values in columns (x axis) instead lines
                      'lin' or 'y': show predicted values in lines   (y axis)
    """
    if pred_val_axis in ("col", "x"):
        xlbl = "Predicted"
        ylbl = "Actual"
    else:
        xlbl = "Actual"
        ylbl = "Predicted"
        df_cm = df_cm.T

    # create "Total" column
    insert_totals(df_cm)

    # this is for print allways in the same window
    fig, ax1 = get_new_fig("Conf matrix default", figsize)

    ax = sn.heatmap(
        df_cm,
        annot=annot,
        annot_kws={"size": 22, "weight": "bold"},
        linewidths=lw,
        ax=ax1,
        cbar=cbar,
        cmap=cmap,
        linecolor="w",
        fmt=fmt,
    )

    # set ticklabels rotation
    ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=22, fontweight = "bold")
    ax.set_yticklabels(ax.get_yticklabels(), rotation=90, fontsize=22, fontweight = "bold")

    # Turn off all the ticks
    for t in ax.xaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False
    for t in ax.yaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False

    # face colors list
    quadmesh = ax.findobj(QuadMesh)[0]
    facecolors = quadmesh.get_facecolors()

    # iter in text elements
    array_df = np.array(df_cm.to_records(index=False).tolist())
    text_add = []
    text_del = []
    posi = -1  # from left to right, bottom to top.
    for t in ax.collections[0].axes.texts:  # ax.texts:
        pos = np.array(t.get_position()) - [0.5, 0.5]
        lin = int(pos[1])
        col = int(pos[0])
        posi += 1
        #print(t)
        #print(pos)
        # set text
        txt_res = configcell_text_and_colors(
            array_df, lin, col, t, facecolors, posi, fz, fmt, show_null_values
        )
        #print(txt_res)
        text_add.extend(txt_res[0])
        text_del.extend(txt_res[1])

    # remove the old ones
    for item in text_del:
        item.remove()
    # append the new ones
    for item in text_add:
        ax.text(item["x"], item["y"], item["text"], **item["kw"])

    # titles and legends
    ax.set_title("Confusion matrix", fontsize=22, fontweight = "bold")
    ax.set_xlabel(xlbl, fontsize=22, labelpad=1, fontweight = "bold")
    ax.set_ylabel(ylbl, fontsize=22, labelpad=1, fontweight = "bold")
    #plt.tight_layout()  # set layout slim
    plt.savefig('dens_confusion.pdf', dpi=300)
    plt.show()


def pp_matrix_from_data(
    y_test,
    predictions,
    columns=None,
    annot=True,
    cmap="Oranges",
    fmt=".2f",
    fz=22,
    lw=0.5,
    cbar=False,
    figsize=[8, 8],
    show_null_values=0,
    pred_val_axis="lin",
):
    """
    plot confusion matrix function with y_test (actual values) and predictions (predic),
    whitout a confusion matrix yet
    """
    from pandas import DataFrame
    from sklearn.metrics import confusion_matrix

    # data
    if not columns:
        from string import ascii_uppercase

        columns = [
            "class %s" % (i)
            for i in list(ascii_uppercase)[0 : len(np.unique(y_test))]
        ]

    confm = confusion_matrix(y_test, predictions)
    fz = 22
    figsize = [8, 8]
    show_null_values = 2
    df_cm = DataFrame(confm, index=columns, columns=columns)
    pp_matrix_tej(
        df_cm,
        fz=fz,
        cmap=cmap,
        figsize=figsize,
        show_null_values=show_null_values,
        pred_val_axis=pred_val_axis,
    )

# %%
df_cm = pd.DataFrame(cf_matrix, index=range(0, 4), columns=range(0, 4))

# %%
#https://github.com/wcipriano/pretty-print-confusion-matrix/blob/master/README.md
pp_matrix_tej(df_cm,cmap = 'Greens',annot=True, lw=0.5, show_null_values=0)

# %%
sums = []
for i in range(cf_matrix.shape[0]):
  sums.append(np.sum(cf_matrix[i,:]))

# %%
sums_p = []
for i in range(cf_matrix.shape[1]):
  sums.append(np.sum(cf_matrix[i,:]))

# %%
sums
# Out:
# [3132, 342, 6192, 2238, 3132, 342, 6192, 2238]

# %%
from sklearn import metrics
print(metrics.classification_report(y_test1,y_pred_saved))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      3132
#            1       0.99      0.98      0.98       342
#            2       0.97      0.97      0.97      6192
#            3       0.96      0.96      0.96      2238
#
#     accuracy                           0.97     11904
#    macro avg       0.97      0.97      0.97     11904
# weighted avg       0.97      0.97      0.97     11904

# %%
plt.plot(m.history['loss'])
plt.plot(m.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
